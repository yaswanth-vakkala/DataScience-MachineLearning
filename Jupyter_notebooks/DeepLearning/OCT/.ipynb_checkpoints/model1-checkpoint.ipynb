# %%
import numpy as np
np.random.seed(800)
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow import keras
from PIL import Image
os.environ['KERAS_BACKEND'] = 'tensorflow'
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image

# %%
print(os.listdir('../data/OCT'))
print(os.listdir('../data/OCT/train'))
print(os.listdir('../data/OCT/test'))
# Out:
# ['test', 'train']
# ['CNV', 'DME', 'DRUSEN', 'NORMAL']
# ['CNV', 'DME', 'DRUSEN', 'NORMAL']

# %%
normal_train = '../data/OCT/train/NORMAL'
cnv_train = '../data/OCT/train/CNV'
dme_train = '../data/OCT/train/DME'
drusen_train = '../data/OCT/train/DRUSEN'

normal_test = '../data/OCT/test/NORMAL'
cnv_test = '../data/OCT/test/CNV'
dme_test = '../data/OCT/test/DME'
drusen_test = '../data/OCT/test/DRUSEN'

# %%
print(len(os.listdir(cnv_train)))
print(len(os.listdir(dme_train)))
print(len(os.listdir(drusen_train)))
print(len(os.listdir(normal_train)))
print(len(os.listdir(cnv_test)))
print(len(os.listdir(dme_test)))
print(len(os.listdir(drusen_test)))
print(len(os.listdir(normal_test)))
# Out:
# 37205
# 11348
# 8616
# 51140
# 250
# 250
# 250
# 250

# %%
cnv_images = os.listdir(cnv_train)

plt.figure(figsize=(15, 10))

for i in range(6):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(os.path.join(cnv_train, cnv_images[i]))
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    
plt.tight_layout()

# %%
dme_images = os.listdir(dme_train)

plt.figure(figsize=(15, 10))

for i in range(6):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(os.path.join(dme_train, dme_images[i]))
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    
plt.tight_layout()

# %%
drusen_images = os.listdir(drusen_train)

plt.figure(figsize=(15, 10))

for i in range(6):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(os.path.join(drusen_train, drusen_images[i]))
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    
plt.tight_layout()

# %%
normal_images = os.listdir(normal_train)

plt.figure(figsize=(15, 10))

for i in range(6):
    plt.subplot(3, 3, i + 1)
    img = plt.imread(os.path.join(normal_train, normal_images[i]))
    plt.imshow(img, cmap='gray')
    plt.axis('off')
    
plt.tight_layout()

# %%
image_generator = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    samplewise_center=True,
    samplewise_std_normalization=True
)

# %%
train = image_generator.flow_from_directory('../data/OCT/train', 
                                            batch_size=8, 
                                            shuffle=True, 
                                            class_mode='binary',
                                            target_size=(180, 180))

test = image_generator.flow_from_directory('../data/OCT/test', 
                                            batch_size=1, 
                                            shuffle=False, 
                                            class_mode='binary',
                                            target_size=(180, 180))
# Out:
# Found 108309 images belonging to 4 classes.
# Found 1000 images belonging to 4 classes.

# %%
print(train.class_indices.keys())
print(train.class_indices['CNV'])
print(train.class_indices['DME'])
print(train.class_indices['DRUSEN'])
print(train.class_indices['NORMAL'])
# Out:
# dict_keys(['CNV', 'DME', 'DRUSEN', 'NORMAL'])
# 0
# 1
# 2
# 3

# %%
w0 = len(os.listdir(cnv_train)) / (len(os.listdir(cnv_train)) + len(os.listdir(dme_train)) + len(os.listdir(drusen_train)) + len(os.listdir(normal_train)))
w1 = len(os.listdir(dme_train)) / (len(os.listdir(cnv_train)) + len(os.listdir(dme_train)) + len(os.listdir(drusen_train)) + len(os.listdir(normal_train)))
w2 = len(os.listdir(drusen_train)) / (len(os.listdir(cnv_train)) + len(os.listdir(dme_train)) + len(os.listdir(drusen_train)) + len(os.listdir(normal_train)))
w3 = len(os.listdir(normal_train)) / (len(os.listdir(cnv_train)) + len(os.listdir(dme_train)) + len(os.listdir(drusen_train)) + len(os.listdir(normal_train)))

class_weight = {0: w0, 1: w1, 2: w2, 3: w3}

print(f"Weight for class 0: {w0:.2f}")
print(f"Weight for class 1: {w1:.2f}")
print(f"Weight for class 2: {w2:.2f}")
print(f"Weight for class 3: {w3:.2f}")
# Out:
# Weight for class 0: 0.34
# Weight for class 1: 0.10
# Weight for class 2: 0.08
# Weight for class 3: 0.47

# %%
model = Sequential()

model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(180, 180, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=32, kernel_size=(3, 3), input_shape=(180, 180, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(filters=128, kernel_size=(3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))

model.compile(loss='categorical_crossentropy', 
              optimizer='adam', 
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_18 (Conv2D)          (None, 178, 178, 32)      896
#
#  batch_normalization_18 (Bat  (None, 178, 178, 32)     128
#  chNormalization)
#
#  conv2d_19 (Conv2D)          (None, 176, 176, 32)      9248
#
#  batch_normalization_19 (Bat  (None, 176, 176, 32)     128
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 88, 88, 32)       0
#  2D)
#
#  conv2d_20 (Conv2D)          (None, 86, 86, 64)        18496
#
#  batch_normalization_20 (Bat  (None, 86, 86, 64)       256
#  chNormalization)
#
#  conv2d_21 (Conv2D)          (None, 84, 84, 64)        36928
#
#  batch_normalization_21 (Bat  (None, 84, 84, 64)       256
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 42, 42, 64)       0
#  g2D)
#
#  conv2d_22 (Conv2D)          (None, 40, 40, 128)       73856
#
# ...

# %%
trained_model = model.fit(
    train, 
    epochs=12,
    # validation_data=validation, 
    class_weight=class_weight,
    steps_per_epoch=100,
    # validation_steps=25,
)
# Out:
# Epoch 1/12
#  28/100 [=======>......................] - ETA: 24s - loss: 0.0000e+00 - accuracy: 0.1429
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 trained_model = model.fit(
#       2     train,
#       3     epochs=12,
#       4     # validation_data=validation,
#       5     class_weight=class_weight,
#       6     steps_per_epoch=100,
#       7     # validation_steps=25,
#       8 )
#
# File ~/miniconda3/envs/tf/lib/python3.9/site-packages/keras/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...
