# %%
import os
import numpy as np
from music21 import converter, instrument, note, chord, stream
import tensorflow as tf
from tensorflow import keras
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Activation

# %%
music_paths = [os.path.join('../data/mozart',ele) for ele in os.listdir("../data/mozart/")]
print("Number of files are:", len(music_paths))
# Out:
# Number of files are: 12

# %%
music_files = []
for i in music_paths:
    if i.endswith('.mid') or i.endswith('.midi'):
        temp = converter.parse(i)
        music_files.append(temp)
print(music_files)
# Out:
# [<music21.stream.Score 0x7f943c57d4c0>, <music21.stream.Score 0x7f943aef14c0>, <music21.stream.Score 0x7f943a15c730>, <music21.stream.Score 0x7f943858bfd0>, <music21.stream.Score 0x7f9436e45880>, <music21.stream.Score 0x7f943403cb50>, <music21.stream.Score 0x7f943a14b100>, <music21.stream.Score 0x7f943328feb0>, <music21.stream.Score 0x7f9430d03df0>, <music21.stream.Score 0x7f94328beeb0>, <music21.stream.Score 0x7f942e788eb0>, <music21.stream.Score 0x7f942e7776a0>]

# %%
notes = []
pick = None

for file in music_files:
    song = instrument.partitionByInstrument(file)
    for part in song.parts:
        pick = part.recurse()
        for element in pick:
            if isinstance(element, note.Note):
                notes.append(str(element.pitch))
            elif isinstance(element, chord.Chord):
                notes.append(".".join(str(n) for n in element.normalOrder))

# %%
print(notes[:40])
# Out:
# ['2.6.9', '9.2', 'G5', '2.6', 'F#5', 'E5', 'F#5', 'A5', '4.7', 'G5', 'F#5', 'G5', 'A5', '6.9', 'A5', 'B5', 'C#6', 'D6', 'A5', 'F#3', 'D4', 'F#5', 'D3', 'D4', 'A5', 'E3', 'G5', 'F#5', 'D4', 'G5', 'A5', 'A3', 'G5', 'C#4', 'F5', '2', 'F#5', 'G5', '2.6', 'F#5']

# %%
print("Total no of notes in all music files in the data set:",len(notes))
# Out:
# Total no of notes in all music files in the data set: 36394

# %%
unique_notes = len(set(notes))
print("Total no of unique notes in all of the music files",unique_notes)
# Out:
# Total no of unique notes in all of the music files 214

# %%
notesnames = sorted(set(notes))
print(notesnames)
# Out:
# ['0', '0.1', '0.1.3', '0.2', '0.2.6', '0.2.7', '0.3', '0.3.5', '0.3.6', '0.3.6.9', '0.3.7', '0.4', '0.4.6', '0.4.7', '0.5', '0.6', '1', '1.2', '1.2.4', '1.3', '1.3.7', '1.4', '1.4.7', '1.4.7.10', '1.4.7.9', '1.6', '1.7', '10', '10.0', '10.0.2', '10.0.4', '10.1', '10.1.4', '10.11', '10.11.1', '10.2', '10.2.5', '10.3', '11', '11.0', '11.0.2', '11.1', '11.1.2', '11.2', '11.2.4', '11.2.5', '11.2.5.7', '11.2.6', '11.3', '11.3.6', '11.4', '2', '2.3', '2.3.5', '2.4', '2.4.5', '2.4.6', '2.4.8', '2.4.9', '2.5', '2.5.7', '2.5.8', '2.5.8.11', '2.5.9', '2.6', '2.6.9', '2.7', '2.8', '3', '3.4', '3.4.5', '3.4.6', '3.5', '3.5.7', '3.6', '3.6.9', '3.7', '3.7.10', '3.8', '3.9', '4', '4.10', '4.5', '4.5.7', '4.6', '4.6.7', '4.6.8', '4.7', '4.7.10', '4.7.10.0', '4.7.11', '4.7.9', '4.8', '4.8.11', '4.9', '5', '5.10', '5.11', '5.6', '5.7', '5.7.11', '5.7.9', '5.8', '5.9', '5.9.0', '6', '6.10', '6.10.1', '6.11', '6.7', '6.7.9', '6.8', '6.9', '6.9.0', '6.9.0.2', '6.9.11', '7', '7.0', '7.10', '7.10.0', '7.10.1', '7.10.2', '7.11', '7.11.2', '7.8', '7.8.10', '7.9', '7.9.1', '7.9.11', '8', '8.0', '8.1', '8.10', '8.10.2', '8.11', '8.11.1.4', '8.11.2', '8.11.2.4', '8.9', '8.9.11', '9', '9.0', '9.0.2', '9.0.3', '9.0.4', '9.1', '9.1.2.4', '9.1.4', '9.10', '9.10.0', '9.11', '9.11.0', '9.11.0.2', '9.11.1', '9.11.3', '9.2', 'A1', 'A2', 'A3', 'A4', 'A5', 'B-1', 'B-2', 'B-3', 'B-4', 'B-5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C#2', 'C#3', 'C#4', 'C#5', 'C#6', 'C2', 'C3', 'C4', 'C5', 'C6', 'D2', 'D3', 'D4', 'D5', 'D6', 'E-2', 'E-3', 'E-4', 'E-5', 'E-6', 'E2', 'E3', 'E4', 'E5', 'E6', 'F#2', 'F#3', 'F#4', 'F#5', 'F2', 'F3', 'F4', 'F5', 'F6', 'G#2', 'G#3', 'G#4', 'G#5', 'G2', 'G3', 'G4', 'G5', 'G6']

# %%
note_to_int = dict((element , i) for i , element in enumerate(notesnames))
print(note_to_int)
# Out:
# {'0': 0, '0.1': 1, '0.1.3': 2, '0.2': 3, '0.2.6': 4, '0.2.7': 5, '0.3': 6, '0.3.5': 7, '0.3.6': 8, '0.3.6.9': 9, '0.3.7': 10, '0.4': 11, '0.4.6': 12, '0.4.7': 13, '0.5': 14, '0.6': 15, '1': 16, '1.2': 17, '1.2.4': 18, '1.3': 19, '1.3.7': 20, '1.4': 21, '1.4.7': 22, '1.4.7.10': 23, '1.4.7.9': 24, '1.6': 25, '1.7': 26, '10': 27, '10.0': 28, '10.0.2': 29, '10.0.4': 30, '10.1': 31, '10.1.4': 32, '10.11': 33, '10.11.1': 34, '10.2': 35, '10.2.5': 36, '10.3': 37, '11': 38, '11.0': 39, '11.0.2': 40, '11.1': 41, '11.1.2': 42, '11.2': 43, '11.2.4': 44, '11.2.5': 45, '11.2.5.7': 46, '11.2.6': 47, '11.3': 48, '11.3.6': 49, '11.4': 50, '2': 51, '2.3': 52, '2.3.5': 53, '2.4': 54, '2.4.5': 55, '2.4.6': 56, '2.4.8': 57, '2.4.9': 58, '2.5': 59, '2.5.7': 60, '2.5.8': 61, '2.5.8.11': 62, '2.5.9': 63, '2.6': 64, '2.6.9': 65, '2.7': 66, '2.8': 67, '3': 68, '3.4': 69, '3.4.5': 70, '3.4.6': 71, '3.5': 72, '3.5.7': 73, '3.6': 74, '3.6.9': 75, '3.7': 76, '3.7.10': 77, '3.8': 78, '3.9': 79, '4': 80, '4.10': 81, '4.5': 82, '4.5.7': 83, '4.6': 84, '4.6.7': 85, '4.6.8': 86, '4.7': 87, '4.7.10': 88, '4.7.10.0': 89, '4.7.11': 90, '4.7.9': 91, '4.8': 92, '4.8.11': 93, '4.9': 94, '5': 95, '5.10': 96, '5.11': 97, '5.6': 98, '5.7': 99, '5.7.11': 100, '5.7.9': 101, '5.8': 102, '5.9': 103, '5.9.0': 104, '6': 105, '6.10': 106, '6.10.1': 107, '6.11': 108, '6.7': 109, '6.7.9': 110, '6.8': 111, '6.9': 112, '6.9.0': 113, '6.9.0.2': 114, '6.9.11': 115, '7': 116, '7.0': 117, '7.10': 118, '7.10.0': 119, '7.10.1': 120, '7.10.2': 121, '7.11': 122, '7.11.2': 123, '7.8': 124, '7.8.10': 125, '7.9': 126, '7.9.1': 127, '7.9.11': 128, '8': 129, '8.0': 130, '8.1': 131, '8.10': 132, '8.10.2': 133, '8.11': 134, '8.11.1.4': 135, '8.11.2': 136, '8.11.2.4': 137, '8.9': 138, '8.9.11': 139, '9': 140, '9.0': 141, '9.0.2': 142, '9.0.3': 143, '9.0.4': 144, '9.1': 145, '9.1.2.4': 146, '9.1.4': 147, '9.10': 148, '9.10.0': 149, '9.11': 150, '9.11.0': 151, '9.11.0.2': 152, '9.11.1': 153, '9.11.3': 154, '9.2': 155, 'A1': 156, 'A2': 157, 'A3': 158, 'A4': 159, 'A5': 160, 'B-1': 161, 'B-2': 162, 'B-3': 163, 'B-4': 164, 'B-5': 165, 'B1': 166, 'B2': 167, 'B3': 168, 'B4': 169, 'B5': 170, 'C#2': 171, 'C#3': 172, 'C#4': 173, 'C#5': 174, 'C#6': 175, 'C2': 176, 'C3': 177, 'C4': 178, 'C5': 179, 'C6': 180, 'D2': 181, 'D3': 182, 'D4': 183, 'D5': 184, 'D6': 185, 'E-2': 186, 'E-3': 187, 'E-4': 188, 'E-5': 189, 'E-6': 190, 'E2': 191, 'E3': 192, 'E4': 193, 'E5': 194, 'E6': 195, 'F#2': 196, 'F#3': 197, 'F#4': 198, 'F#5': 199, 'F2': 200, 'F3': 201, 'F4': 202, 'F5': 203, 'F6': 204, 'G#2': 205, 'G#3': 206, 'G#4': 207, 'G#5': 208, 'G2': 209, 'G3': 210, 'G4': 211, 'G5': 212, 'G6': 213}

# %%
int_to_note = {i:element for element , i in note_to_int.items()}
print(int_to_note)
# Out:
# {0: '0', 1: '0.1', 2: '0.1.3', 3: '0.2', 4: '0.2.6', 5: '0.2.7', 6: '0.3', 7: '0.3.5', 8: '0.3.6', 9: '0.3.6.9', 10: '0.3.7', 11: '0.4', 12: '0.4.6', 13: '0.4.7', 14: '0.5', 15: '0.6', 16: '1', 17: '1.2', 18: '1.2.4', 19: '1.3', 20: '1.3.7', 21: '1.4', 22: '1.4.7', 23: '1.4.7.10', 24: '1.4.7.9', 25: '1.6', 26: '1.7', 27: '10', 28: '10.0', 29: '10.0.2', 30: '10.0.4', 31: '10.1', 32: '10.1.4', 33: '10.11', 34: '10.11.1', 35: '10.2', 36: '10.2.5', 37: '10.3', 38: '11', 39: '11.0', 40: '11.0.2', 41: '11.1', 42: '11.1.2', 43: '11.2', 44: '11.2.4', 45: '11.2.5', 46: '11.2.5.7', 47: '11.2.6', 48: '11.3', 49: '11.3.6', 50: '11.4', 51: '2', 52: '2.3', 53: '2.3.5', 54: '2.4', 55: '2.4.5', 56: '2.4.6', 57: '2.4.8', 58: '2.4.9', 59: '2.5', 60: '2.5.7', 61: '2.5.8', 62: '2.5.8.11', 63: '2.5.9', 64: '2.6', 65: '2.6.9', 66: '2.7', 67: '2.8', 68: '3', 69: '3.4', 70: '3.4.5', 71: '3.4.6', 72: '3.5', 73: '3.5.7', 74: '3.6', 75: '3.6.9', 76: '3.7', 77: '3.7.10', 78: '3.8', 79: '3.9', 80: '4', 81: '4.10', 82: '4.5', 83: '4.5.7', 84: '4.6', 85: '4.6.7', 86: '4.6.8', 87: '4.7', 88: '4.7.10', 89: '4.7.10.0', 90: '4.7.11', 91: '4.7.9', 92: '4.8', 93: '4.8.11', 94: '4.9', 95: '5', 96: '5.10', 97: '5.11', 98: '5.6', 99: '5.7', 100: '5.7.11', 101: '5.7.9', 102: '5.8', 103: '5.9', 104: '5.9.0', 105: '6', 106: '6.10', 107: '6.10.1', 108: '6.11', 109: '6.7', 110: '6.7.9', 111: '6.8', 112: '6.9', 113: '6.9.0', 114: '6.9.0.2', 115: '6.9.11', 116: '7', 117: '7.0', 118: '7.10', 119: '7.10.0', 120: '7.10.1', 121: '7.10.2', 122: '7.11', 123: '7.11.2', 124: '7.8', 125: '7.8.10', 126: '7.9', 127: '7.9.1', 128: '7.9.11', 129: '8', 130: '8.0', 131: '8.1', 132: '8.10', 133: '8.10.2', 134: '8.11', 135: '8.11.1.4', 136: '8.11.2', 137: '8.11.2.4', 138: '8.9', 139: '8.9.11', 140: '9', 141: '9.0', 142: '9.0.2', 143: '9.0.3', 144: '9.0.4', 145: '9.1', 146: '9.1.2.4', 147: '9.1.4', 148: '9.10', 149: '9.10.0', 150: '9.11', 151: '9.11.0', 152: '9.11.0.2', 153: '9.11.1', 154: '9.11.3', 155: '9.2', 156: 'A1', 157: 'A2', 158: 'A3', 159: 'A4', 160: 'A5', 161: 'B-1', 162: 'B-2', 163: 'B-3', 164: 'B-4', 165: 'B-5', 166: 'B1', 167: 'B2', 168: 'B3', 169: 'B4', 170: 'B5', 171: 'C#2', 172: 'C#3', 173: 'C#4', 174: 'C#5', 175: 'C#6', 176: 'C2', 177: 'C3', 178: 'C4', 179: 'C5', 180: 'C6', 181: 'D2', 182: 'D3', 183: 'D4', 184: 'D5', 185: 'D6', 186: 'E-2', 187: 'E-3', 188: 'E-4', 189: 'E-5', 190: 'E-6', 191: 'E2', 192: 'E3', 193: 'E4', 194: 'E5', 195: 'E6', 196: 'F#2', 197: 'F#3', 198: 'F#4', 199: 'F#5', 200: 'F2', 201: 'F3', 202: 'F4', 203: 'F5', 204: 'F6', 205: 'G#2', 206: 'G#3', 207: 'G#4', 208: 'G#5', 209: 'G2', 210: 'G3', 211: 'G4', 212: 'G5', 213: 'G6'}

# %%
seq_len = 100

# %%
nn_input = []   
nn_output = []

for i in range(len(notes) - seq_len):
    seq_in = notes[i : i+seq_len]    
    seq_out = notes[i+seq_len]
    nn_input.append([note_to_int[n] for n in seq_in])
    nn_output.append(note_to_int[seq_out])
    
print(nn_input[:5])
print("-----------------")
print(nn_output[:5])
# Out:
# [[65, 155, 212, 64, 199, 194, 199, 160, 87, 212, 199, 212, 160, 112, 160, 170, 175, 185, 160, 197, 183, 199, 182, 183, 160, 192, 212, 199, 183, 212, 160, 158, 212, 173, 203, 51, 199, 212, 64, 199, 194, 199, 160, 87, 212, 199, 212, 160, 112, 160, 170, 175, 185, 160, 197, 183, 199, 182, 183, 160, 192, 212, 199, 183, 212, 160, 158, 212, 199, 173, 194, 184, 183, 198, 159, 183, 198, 109, 183, 109, 198, 109, 109, 183, 199, 194, 198, 184, 174, 193, 211, 159, 193, 211, 194, 193, 198, 211, 198, 193], [155, 212, 64, 199, 194, 199, 160, 87, 212, 199, 212, 160, 112, 160, 170, 175, 185, 160, 197, 183, 199, 182, 183, 160, 192, 212, 199, 183, 212, 160, 158, 212, 173, 203, 51, 199, 212, 64, 199, 194, 199, 160, 87, 212, 199, 212, 160, 112, 160, 170, 175, 185, 160, 197, 183, 199, 182, 183, 160, 192, 212, 199, 183, 212, 160, 158, 212, 199, 173, 194, 184, 183, 198, 159, 183, 198, 109, 183, 109, 198, 109, 109, 183, 199, 194, 198, 184, 174, 193, 211, 159, 193, 211, 194, 193, 198, 211, 198, 193, 183], [212, 64, 199, 194, 199, 160, 87, 212, 199, 212, 160, 112, 160, 170, 175, 185, 160, 197, 183, 199, 182, 183, 160, 192, 212, 199, 183, 212, 160, 158, 212, 173, 203, 51, 199, 212, 64, 199, 194, 199, 160, 87, 212, 199, 212, 160, 112, 160, 170, 175, 185, 160, 197, 183, 199, 182, 183, 160, 192, 212, 199, 183, 212, 160, 158, 212, 199, 173, 194, 184, 183, 198, 159, 183, 198, 109, 183, 109, 198, 109, 109, 183, 199, 194, 198, 184, 174, 193, 211, 159, 193, 211, 194, 193, 198, 211, 198, 193, 183, 173], [64, 199, 194, 199, 160, 87, 212, 199, 212, 160, 112, 160, 170, 175, 185, 160, 197, 183, 199, 182, 183, 160, 192, 212, 199, 183, 212, 160, 158, 212, 173, 203, 51, 199, 212, 64, 199, 194, 199, 160, 87, 212, 199, 212, 160, 112, 160, 170, 175, 185, 160, 197, 183, 199, 182, 183, 160, 192, 212, 199, 183, 212, 160, 158, 212, 199, 173, 194, 184, 183, 198, 159, 183, 198, 109, 183, 109, 198, 109, 109, 183, 199, 194, 198, 184, 174, 193, 211, 159, 193, 211, 194, 193, 198, 211, 198, 193, 183, 173, 168], [199, 194, 199, 160, 87, 212, 199, 212, 160, 112, 160, 170, 175, 185, 160, 197, 183, 199, 182, 183, 160, 192, 212, 199, 183, 212, 160, 158, 212, 173, 203, 51, 199, 212, 64, 199, 194, 199, 160, 87, 212, 199, 212, 160, 112, 160, 170, 175, 185, 160, 197, 183, 199, 182, 183, 160, 192, 212, 199, 183, 212, 160, 158, 212, 199, 173, 194, 184, 183, 198, 159, 183, 198, 109, 183, 109, 198, 109, 109, 183, 199, 194, 198, 184, 174, 193, 211, 159, 193, 211, 194, 193, 198, 211, 198, 193, 183, 173, 168, 194]]
# -----------------
# [183, 173, 168, 194, 158]

# %%
print(len(nn_input))
print(len(nn_output))
# Out:
# 36294
# 36294

# %%
np.asarray(nn_input).shape
# Out:
# (36294, 100)

# %%
norm_nn_input = np.asarray(nn_input).reshape((-1, seq_len, 1))
print(norm_nn_input.shape)
# Out:
# (36294, 100, 1)

# %%
norm_nn_input = norm_nn_input/float(unique_notes)

# %%
nn_output = to_categorical(nn_output)

# %%
print(norm_nn_input.shape)
print(nn_output.shape)
# Out:
# (36294, 100, 1)
# (36294, 214)

# %%
model = Sequential()
model.add(LSTM(units = 512 , input_shape = (norm_nn_input.shape[1], norm_nn_input.shape[2]), return_sequences = True))
model.add(Dropout(0.4))

model.add(LSTM(units = 512 , return_sequences = True))
model.add(Dropout(0.4))
model.add(LSTM(units = 512))

model.add(Dense(256))
model.add(Dropout(0.3))
model.add(Dense(unique_notes , activation = 'softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100, 512)          1052672
#
#  dropout (Dropout)           (None, 100, 512)          0
#
#  lstm_1 (LSTM)               (None, 100, 512)          2099200
#
#  dropout_1 (Dropout)         (None, 100, 512)          0
#
#  lstm_2 (LSTM)               (None, 512)               2099200
#
#  dense (Dense)               (None, 256)               131328
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 214)               54998
#
# =================================================================
# Total params: 5,437,398
# Trainable params: 5,437,398
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = "categorical_crossentropy")

# %%
trained_model = model.fit(norm_nn_input, nn_output, epochs = 50, batch_size = 64)
# Out:
# Epoch 1/50
# 568/568 [==============================] - 117s 198ms/step - loss: 4.2952
# Epoch 2/50
# 568/568 [==============================] - 117s 205ms/step - loss: 4.2021
# Epoch 3/50
# 568/568 [==============================] - 115s 202ms/step - loss: 4.1354
# Epoch 4/50
# 568/568 [==============================] - 116s 204ms/step - loss: 4.0343
# Epoch 5/50
# 568/568 [==============================] - 116s 205ms/step - loss: 3.9444
# Epoch 6/50
# 568/568 [==============================] - 108s 190ms/step - loss: 3.8527
# Epoch 7/50
# 568/568 [==============================] - 86s 152ms/step - loss: 3.7468
# Epoch 8/50
# 568/568 [==============================] - 90s 158ms/step - loss: 3.6398
# Epoch 9/50
# 568/568 [==============================] - 88s 154ms/step - loss: 3.5129
# Epoch 10/50
# 568/568 [==============================] - 89s 157ms/step - loss: 3.3800
# Epoch 11/50
# 568/568 [==============================] - 90s 158ms/step - loss: 3.2259
# Epoch 12/50
# 568/568 [==============================] - 90s 159ms/step - loss: 3.0554
# Epoch 13/50
# 568/568 [==============================] - 90s 159ms/step - loss: 2.8675
# Epoch 14/50
# 568/568 [==============================] - 91s 160ms/step - loss: 2.6847
# Epoch 15/50
# 568/568 [==============================] - 91s 161ms/step - loss: 2.4681
# Epoch 16/50
# 568/568 [==============================] - 91s 161ms/step - loss: 2.2687
# Epoch 17/50
# 568/568 [==============================] - 92s 161ms/step - loss: 2.0888
# Epoch 18/50
# 568/568 [==============================] - 91s 161ms/step - loss: 1.9090
# Epoch 19/50
# 568/568 [==============================] - 92s 162ms/step - loss: 1.7701
# Epoch 20/50
# 568/568 [==============================] - 92s 162ms/step - loss: 1.6067
# Epoch 21/50
# 568/568 [==============================] - 92s 162ms/step - loss: 1.4812
# Epoch 22/50
# 568/568 [==============================] - 92s 162ms/step - loss: 1.3540
# Epoch 23/50
# 568/568 [==============================] - 92s 161ms/step - loss: 1.2404
# Epoch 24/50
# 568/568 [==============================] - 92s 162ms/step - loss: 1.1253
# Epoch 25/50
# 568/568 [==============================] - 92s 162ms/step - loss: 1.0433
# Epoch 26/50
# 568/568 [==============================] - 92s 162ms/step - loss: 0.9604
# Epoch 27/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.8750
# Epoch 28/50
# 568/568 [==============================] - 93s 164ms/step - loss: 0.8098
# Epoch 29/50
# 568/568 [==============================] - 93s 164ms/step - loss: 0.7489
# Epoch 30/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.6879
# Epoch 31/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.6407
# Epoch 32/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.6162
# Epoch 33/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.5665
# Epoch 34/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.5245
# Epoch 35/50
# 568/568 [==============================] - 93s 164ms/step - loss: 0.4880
# Epoch 36/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.4801
# Epoch 37/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.4384
# Epoch 38/50
# 568/568 [==============================] - 93s 164ms/step - loss: 0.4318
# Epoch 39/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.4041
# Epoch 40/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.3703
# Epoch 41/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.3557
# Epoch 42/50
# 568/568 [==============================] - 93s 164ms/step - loss: 0.3453
# Epoch 43/50
# 568/568 [==============================] - 94s 166ms/step - loss: 0.3278
# Epoch 44/50
# 568/568 [==============================] - 93s 165ms/step - loss: 0.3118
# Epoch 45/50
# 568/568 [==============================] - 93s 164ms/step - loss: 0.3212
# Epoch 46/50
# 568/568 [==============================] - 93s 164ms/step - loss: 0.2773
# Epoch 47/50
# 568/568 [==============================] - 93s 164ms/step - loss: 0.2721
# Epoch 48/50
# 568/568 [==============================] - 93s 163ms/step - loss: 0.2819
# Epoch 49/50
# 568/568 [==============================] - 93s 164ms/step - loss: 0.2696
# Epoch 50/50
# 568/568 [==============================] - 93s 164ms/step - loss: 0.2521

# %%
model.save('latest_model.keras')

# %%
model.save('latest_modelh.h5')
