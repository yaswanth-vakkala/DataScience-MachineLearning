# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/content/drive/MyDrive/data_files/pnjb.xlsx", sheet_name=1)

# %%
df
# Out:
#       Year    Primary  Secondary    Tertiary
# 0  2011-12  7820507.0  6444053.0  11112867.0
# 1  2012-13  7888818.0  6587581.0  12063717.0
# 2  2013-14  8154996.0  6895147.0  12874958.0
# 3  2014-15  7874299.0  7245721.0  13889371.0
# 4  2015-16  7979559.0  7693319.0  14847996.0
# 5  2016-17  8479201.0  8166126.0  15839220.0
# 6  2017-18  8885721.0  8659066.0  16923837.0
# 7  2018-19  9097140.0  9093988.0  18103343.0
# 8  2019-20  9261138.0  9299817.0  19219524.0
# 9  2020-21  9534346.0  9328654.0  18288453.0

# %%
df.columns
# Out:
# Index(['Year', 'Primary', 'Secondary', 'Tertiary'], dtype='object')

# %%
dfc = df.copy()

# %%
df = df.drop(['Year'], axis=1)

# %%
y1 = df.iloc[0]
mylabels = ["Agriculture", "Industrial", "Services"]

plt.pie(y1, labels=mylabels, autopct='%1.1f%%')
plt.title("Sector Shares 2011 -12")
plt.show()

# %%
y2 = df.iloc[1]
mylabels = ["Agriculture", "Industrial", "Services"]

plt.pie(y2, labels=mylabels, autopct='%1.1f%%')
plt.title("Sector Shares 2012 -13")
plt.show()

# %%
y3 = df.iloc[2]
mylabels = ["Agriculture", "Industrial", "Services"]

plt.pie(y3, labels=mylabels, autopct='%1.1f%%')
plt.title("Sector Shares 2013 -14")
plt.show()

# %%
y4 = df.iloc[3]
mylabels = ["Agriculture", "Industrial", "Services"]

plt.pie(y4, labels=mylabels, autopct='%1.1f%%')
plt.title("Sector Shares 2014 -15")
plt.show()

# %%
y5 = df.iloc[4]
mylabels = ["Agriculture", "Industrial", "Services"]

plt.pie(y5, labels=mylabels, autopct='%1.1f%%')
plt.title("Sector Shares 2015 -16")
plt.show()

# %%
y6 = df.iloc[5]
mylabels = ["Agriculture", "Industrial", "Services"]

plt.pie(y6, labels=mylabels, autopct='%1.1f%%')
plt.title("Sector Shares 2016 -17")
plt.show()

# %%
y7 = df.iloc[6]
mylabels = ["Agriculture", "Industrial", "Services"]

plt.pie(y7, labels=mylabels, autopct='%1.1f%%')
plt.title("Sector Shares 2017 -18")
plt.show()

# %%
y8 = df.iloc[7]
mylabels = ["Agriculture", "Industrial", "Services"]

plt.pie(y8, labels=mylabels, autopct='%1.1f%%')
plt.title("Sector Shares 2018 -19")
plt.show()

# %%
y9 = df.iloc[8]
mylabels = ["Agriculture", "Industrial", "Services"]

plt.pie(y9, labels=mylabels, autopct='%1.1f%%')
plt.title("Sector Shares 2019 -20")
plt.show()

# %%
y10 = df.iloc[9]
mylabels = ["Agriculture", "Industrial", "Services"]

plt.pie(y10, labels=mylabels, autopct='%1.1f%%')
plt.title("Sector Shares 2020 -21")
plt.show()

# %%
Year = np.array([2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
sns.barplot(x = Year,
            y = 'Primary',
            data = dfc)

plt.show()

# %%
sns.lineplot(x = Year,
            y = 'Primary',
            data = dfc)

plt.show()

# %%
sns.barplot(x = Year,
            y = 'Secondary',
            data = dfc)

plt.show()

# %%
sns.lineplot(x = Year,
            y = 'Secondary',
            data = dfc)

plt.show()

# %%
sns.barplot(x = Year,
            y = 'Tertiary',
            data = dfc)

plt.show()

# %%
sns.lineplot(x = Year,
            y = 'Tertiary',
            data = dfc)

plt.show()

# %%
for i in range(1, len(df['Primary'])):
  rate = (df['Primary'][i] - df['Primary'][i-1]) / df['Primary'][i-1] * 100
  print("Year 20"+str(i+11)+"-"+str(i+12)+" : "+str(rate)+" %")
# Out:
# Year 2012-13 : 0.8734855681351605 %
# Year 2013-14 : 3.3741176434796696 %
# Year 2014-15 : -3.442024986891471 %
# Year 2015-16 : 1.3367539129514894 %
# Year 2016-17 : 6.261523976450328 %
# Year 2017-18 : 4.794319653467349 %
# Year 2018-19 : 2.379311706950961 %
# Year 2019-20 : 1.802742400358794 %
# Year 2020-21 : 2.950047823496421 %

# %%
for i in range(1, len(df['Secondary'])):
  rate = (df['Secondary'][i] - df['Secondary'][i-1]) / df['Secondary'][i-1] * 100
  print("Year 20"+str(i+11)+"-"+str(i+12)+" : "+str(rate)+" %")
# Out:
# Year 2012-13 : 2.2272939095938535 %
# Year 2013-14 : 4.668876177765404 %
# Year 2014-15 : 5.084358607582986 %
# Year 2015-16 : 6.177411468092686 %
# Year 2016-17 : 6.145683027052433 %
# Year 2017-18 : 6.036399634294156 %
# Year 2018-19 : 5.022735708447077 %
# Year 2019-20 : 2.2633524477929816 %
# Year 2020-21 : 0.31008137041836414 %

# %%
for i in range(1, len(df['Tertiary'])):
  rate = (df['Tertiary'][i] - df['Tertiary'][i-1]) / df['Tertiary'][i-1] * 100
  print("Year 20"+str(i+11)+"-"+str(i+12)+" : "+str(rate) + " %")
# Out:
# Year 2012-13 : 8.55629784825104 %
# Year 2013-14 : 6.724635533144552 %
# Year 2014-15 : 7.878961624573844 %
# Year 2015-16 : 6.90186042262101 %
# Year 2016-17 : 6.675809988095363 %
# Year 2017-18 : 6.847666741165284 %
# Year 2018-19 : 6.969495156447087 %
# Year 2019-20 : 6.165607092568483 %
# Year 2020-21 : -4.844401973742951 %
